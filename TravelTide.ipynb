# %% [markdown]
# <a href="https://colab.research.google.com/github/Anastasia8BlackCat/retail_demand_analysis_TravelTide/blob/main/TravelTide.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sqlalchemy as sa
import psycopg2  as pc

# %%
# !pip install psycopg2-binary sqlalchemy pandas

import pandas as pd
from sqlalchemy import create_engine, inspect

url = "postgresql+psycopg2://Test:bQNxVzJL4g6u@ep-noisy-flower-846766.us-east-2.aws.neon.tech/TravelTide"
engine = create_engine(url)

insp = inspect(engine)
tables = insp.get_table_names()

schema = []
for table in tables:
    cols = insp.get_columns(table)
    for c in cols:
        schema.append({"table": table, "column": c['name'], "type": c['type'], "nullable": c['nullable']})

df = pd.DataFrame(schema)
df
# Out:
# ...
#        table                   column       type  nullable
# 0     hotels                  trip_id       TEXT     False
# 1     hotels               hotel_name       TEXT      True
# 2     hotels                   nights    INTEGER      True
# 3     hotels                    rooms    INTEGER      True
# 4     hotels            check_in_time  TIMESTAMP      True
# 5     hotels           check_out_time  TIMESTAMP      True
# 6     hotels       hotel_per_room_usd    NUMERIC      True
# 7      users                  user_id    INTEGER     False
# 8      users                birthdate       DATE      True
# 9      users                   gender       TEXT      True
# 10     users                  married    BOOLEAN      True
# 11     users             has_children    BOOLEAN      True
# 12     users             home_country       TEXT      True
# 13     users                home_city       TEXT      True
# 14     users             home_airport       TEXT      True
# ...

# %%
import pandas as pd
import sqlalchemy as sa

# checking hotels tables
query = """
SELECT *
FROM hotels p;
"""
connection = engine.connect().execution_options(isolation_level="AUTOCOMMIT")
pd.read_sql(sa.text(query),connection)
# Out:
#                                          trip_id  \
# 0        163303-8531be4b43774121ab558b8a0381442a
# 1        163418-9cc5122d5f0744cdbd67add25b6e6203
# 2        163516-1e5e3cfd1b1445e7a2b55e272669d307
# 3        163544-76088eef395b4f8889cb7293fb9ace95
# 4        163637-9e0fbc546f6f4461bd78cccf6f7a9493
# ...                                          ...
# 1918612  162928-d3d447c5df9042ffa36814afec1c474f
# 1918613  163028-3edfe99d055b45459e6f2392f1b62e8a
# 1918614  163117-aede7ae966a3427c89f49a83bb0ef13e
# 1918615  163201-24359b2f09434383ae1e563595d40dd7
# 1918616  163231-28a466a5181d488c947286b82dffe1ea
#
#                            hotel_name  nights  rooms           check_in_time  \
# 0              Banyan Tree  - phoenix       1      2 2022-07-19 12:04:16.500
# 1                   Accor - vancouver       4      3 2022-07-16 18:19:02.910
# 2                     Accor - chicago       3      1 2022-07-15 11:00:00.000
# ...

# %%
import pandas as pd
import sqlalchemy as sa

# checking users tables
query = """
SELECT *
FROM users p;
"""
connection = engine.connect().execution_options(isolation_level="AUTOCOMMIT")
pd.read_sql(sa.text(query),connection)
# Out:
#          user_id   birthdate gender  married  has_children home_country  \
# 0              0  1990-01-22      F    False         False          usa
# 1              1  2000-11-08      M    False         False          usa
# 2              2  1992-09-21      M    False         False          usa
# 3              3  1996-11-27      F    False         False          usa
# 4              4  1978-01-05      M     True          True          usa
# ...          ...         ...    ...      ...           ...          ...
# 1020921  1020921  2005-05-22      M    False          True          usa
# 1020922  1020922  1985-06-15      M     True         False          usa
# 1020923  1020923  1995-09-21      F    False         False       canada
# 1020924  1020924  2006-11-19      F    False         False          usa
# 1020925  1020925  1978-04-27      M    False          True          usa
#
#                 home_city home_airport  home_airport_lat  home_airport_lon  \
# ...

# %%
import pandas as pd
import sqlalchemy as sa

# checking flights tables
query = """
SELECT *
FROM flights p;
"""
connection = engine.connect().execution_options(isolation_level="AUTOCOMMIT")
pd.read_sql(sa.text(query),connection)
# Out:
#                                          trip_id origin_airport  destination  \
# 0        599348-f5cc943324bd4adfa1bfbd28b160505a            RND      houston
# 1        599351-25965d485e5d4173a1c9f867571b5e58            FAT    baltimore
# 2        599406-0fe6d8d9883147aa932a6f42c159dae0            EFD  los angeles
# 3        599409-6d0ee228195f4f2dbb5ede133b2ebeea            RND      toronto
# 4        599426-b176e4ddccbe4667ac571f7fb886b7bb            STL   fort worth
# ...                                          ...            ...          ...
# 1901033  599103-a29ab5cb5a0a4c2c9caaef37ae5985da            ANC     winnipeg
# 1901034  599198-62e70e0405e0448fa5c985ac3c373d99            YYC     new york
# 1901035  599256-a2b623b31fd945c8a2bd818dd6b9ee2b            SFO     new york
# 1901036  599261-0d611e162bd34614b5648c0a12f134ec            TUS  san antonio
# 1901037  599273-3edf03ca7bfc4d4f8ec621d8967eb60a            IAB     new york
#
# ...

# %%
import pandas as pd
import sqlalchemy as sa

# checking sessions tables
query = """
SELECT *
FROM sessions p;
"""
connection = engine.connect().execution_options(isolation_level="AUTOCOMMIT")
pd.read_sql(sa.text(query),connection)
# Out:
#                                       session_id  user_id  \
# 0        208098-563e2e5011bc496180254f5d248db6c7   208098
# 1        208143-a413f6c8ef174896bda584a3d5716a68   208143
# 2        208206-20b27451608a42f4883cd21cb84ba73c   208206
# 3        208238-84b19ad028d34930b17884ffd93438d7   208238
# 4        208274-b9eb914cce1d4017ab75c7e9416b9437   208274
# ...                                          ...      ...
# 5408058  207964-96baa2eef9d045aba44b8f0efee6731b   207964
# 5408059  207977-092454b0851a49bc9c29a2cf2403ce88   207977
# 5408060  208005-a302593175f249f19a2ff8d3bcd940e9   208005
# 5408061  208020-e08468eb46be48b58a0aeb697e9e2d3d   208020
# 5408062  208041-ee5db96114194b5fb0d22dfe6a78ee31   208041
#
#                                          trip_id       session_start  \
# 0        208098-caf5e8ea90c642efaf56fd8949716a2b 2023-01-01 19:43:00
# 1                                           None 2023-01-01 21:11:00
# ...

# %%
# N1 How many customers do we have in the data?
--query = """
--SELECT
--			COUNT(DISTINCT customer_id)
--FROM customers;
--"""
--pd.read_sql(sa.text(query),connection)
